# %% [markdown]
# <a href="https://colab.research.google.com/github/Anantmishra1907/Google-AI-ML/blob/main/cv_with_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# Dataset = fashion_mnsit

# %%
mnsit = tf.keras.datasets.fashion_mnist

# %% [markdown]
# load data to the model

# %%
(training_images, training_labels), (test_images, test_labels) = mnsit.load_data()

# %% [markdown]
# Normalisation

# %%
from IPython.testing import test
training_images = training_images/255.0
test_images = test_images/255.0

# %% [markdown]
# Model designing

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128 , activation = tf.nn.relu),
    tf.keras.layers.Dense(10 , activation = tf.nn.softmax)
])

# %% [markdown]
# compile and training the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(training_images , training_labels , epochs= 7)
# Out:
# Epoch 1/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.6933 - loss: 3.3642
# Epoch 2/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7459 - loss: 0.6894
# Epoch 3/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - accuracy: 0.7984 - loss: 0.5820
# Epoch 4/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8125 - loss: 0.5448
# Epoch 5/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.8204 - loss: 0.5260
# Epoch 6/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8250 - loss: 0.5122
# Epoch 7/7
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8304 - loss: 0.4902

# %% [markdown]
# Test the model : we have test images and test label present theere to evaluate the model

# %%
model.evaluate(test_images , test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8246 - loss: 0.5275
# [0.5274613499641418, 0.8245999813079834]

# %% [markdown]
# This modle is not as accurate as it is on the trained data there is 82.45 percent accuracy
